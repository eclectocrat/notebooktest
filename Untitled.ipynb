# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Initialize the plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 12))

# Plot the data
ax1.bar([1.5, 2, 3.5], [3, 4, 5])
ax2.barh([0.5, 1, 2.5], [0, 1, 2])

# Show the plot
plt.show()

# %%
print("echo")
